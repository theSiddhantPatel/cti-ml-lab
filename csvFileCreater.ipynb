# %%
# add sample data
import pandas as pd
data = [
    ["2025-01-01 09:01:12", "admin", "192.168.1.10", 1, 0, "yes"],
    ["2025-01-01 09:05:43", "john", "192.168.1.15", 2, 1, "yes"],
    ["2025-01-01 09:07:10", "root", "45.83.22.11", 5, 5, "no"]
]

columns = ["timestamp", "username", "ip_address", "login_attempts", "failed_attempts", "success"]

df = pd.DataFrame(data, columns=columns)
df.to_csv("data/auth_logs.csv", index=False)

print("CSV file with sample data created!")
# Out:
# CSV file with sample data created!

# %%
df
# Out:
#              timestamp username    ip_address  login_attempts  \
# 0  2025-01-01 09:01:12    admin  192.168.1.10               1
# 1  2025-01-01 09:05:43     john  192.168.1.15               2
# 2  2025-01-01 09:07:10     root   45.83.22.11               5
#
#    failed_attempts success
# 0                0     yes
# 1                1     yes
# 2                5      no
